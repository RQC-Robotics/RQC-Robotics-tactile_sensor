# %% [markdown]
# <a href="https://colab.research.google.com/github/RQC-Robotics/RQC-Robotics-tactile_sensor/blob/main/exampels/see_resalts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/RQC-Robotics/RQC-Robotics-tactile_sensor

# %%
import pandas as pd
import sensor_lib as sl
import sensor_lib.data_analis as ds
from google.colab import drive
drive.mount('/content/drive')

# %%
path_true='/content/drive/MyDrive/Colab_projects/generated_gauses/fresh_gauss'
path_pred='/content/drive/MyDrive/Colab_projects/results/deep_model_'
inter=(81000,90000)
l=100000
n_ga_mas=[15,30]
n_fi_mas=[1,2,3,4,8,16]
dic=ds.get_dic(n_ga_mas,n_fi_mas, path_true, path_pred, l, inter)
df=pd.DataFrame(dic)

# %%
df15=df[15].copy()
df30=df[30].copy()
df15=df15.sort_values(by = ('loss',16))
df30=df30.sort_values(by = ('loss',16))

# %%
ds.show_datasets({
    15:df15.tail(2),
    30:df30.tail(2)
    })

# %%
# mean_l = df15.groupby(axis=1,level=(2)).mean()['loss'].copy()
# df15[(15,"input","loss")]=mean_l
