# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# %%
file = tf.keras.utils.get_file(
    "file.png",
    "https://wmpics.pics/di-5WU1.png")
img = tf.keras.preprocessing.image.load_img(file, target_size=[224, 224])
plt.imshow(img)
# Out:
# Downloading data from https://wmpics.pics/di-5WU1.png
# 49152/47020 [===============================] - 0s 1us/step
# 57344/47020 [====================================] - 0s 1us/step

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(img)

# %%
transformation = tf.keras.preprocessing.image.apply_affine_transform(
    img,
    theta=270
)
plt.imshow(transformation)

# %%
transformation = tf.keras.preprocessing.image.apply_affine_transform(
    img,
    shear=50
)
plt.imshow(transformation)

# %%
transformation = tf.keras.preprocessing.image.apply_affine_transform(
    img,
    tx=30,
    ty=30
)
plt.imshow(transformation)

# %%
def gaus(x,a):
    return math.exp(-(x/a)**2)

# %%
mas=round_fun((100,100),(50,50),lambda x: gaus(x,5))

# %%
mas2=mas[:,:,np.newaxis]

# %%
plt.imshow(mas)
plt.show()
plt.imshow(mas3)
plt.show()
