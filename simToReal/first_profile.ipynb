# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/amir/rqc_internship/frame_stack

# %%
import numpy as np
import matplotlib.pyplot as plt
from os.path import join as jn
import os
import yaml
import torch
from torchinfo import summary
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader, Dataset

# %%
with open('params.yaml') as conf_file:
    config = yaml.safe_load(conf_file)
with open('pathes.yaml') as conf_file:
    path_config = yaml.safe_load(conf_file)

# %%
config['env']['sen_geometry']['distance'] = 0.1

# %%
# config['sim']['test_mod'] = True

# %%
import torch_sensor_lib as tsl
sim = tsl.FiberSimulator(config)

# %%
point_pressure = np.zeros((64, 64), dtype=np.float32)
point_pressure[31, 31] = 1

# %%
signals = sim.fiber_real_sim(100*point_pressure);
plt.plot(signals[0, 0]);
